# %%
# keep ur wandb keys ready to log the results

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch
print(torch.cuda.is_available())

# %%
import os

# for the stack dataset user needs to be logged in
from huggingface_hub import login
hd_token = os.environ.get('HF_TOKEN')
login(token=hd_token)

# %%
from google.colab import files
files.download("./Lite-GPT/results/generated_text.txt")

# %%
from google.colab import files
files.download("./Lite-GPT/results/benchmark.json")
